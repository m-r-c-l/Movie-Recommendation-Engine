# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
current_directory = os.getcwd()
data_directory = os.path.join(current_directory, '..', 'raw_data')
data_directory = os.path.abspath(data_directory)
data_directory
# Out:
# '/Users/timjamboula/code/m-r-c-l/Movie-Recommendation-Engine/raw_data'

# %%
# Load each CSV file into a DataFrame
links_df = pd.read_csv(os.path.join(data_directory, 'ml-latest-small/links.csv'))
ratings_df = pd.read_csv(os.path.join(data_directory, 'ml-latest-small/ratings.csv'))
tags_df = pd.read_csv(os.path.join(data_directory, 'ml-latest-small/tags.csv'))
movies_df = pd.read_csv(os.path.join(data_directory, 'ml-latest-small/movies.csv'))

# %%
# Extracting release year from title
movies_df['year'] = movies_df['title'].str.extract(r'\((\d{4})\)')
movies_df['genres'] = movies_df['genres'].str.split('|')
movies_df['title'] = movies_df['title'].str.replace(r'\(\d{4}\)', '').str.strip()

# %%
movies_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                                  genres  year
# 0     [Adventure, Animation, Children, Comedy, Fantasy]  1995
# 1                        [Adventure, Children, Fantasy]  1995
# 2                                     [Comedy, Romance]  1995
# 3                              [Comedy, Drama, Romance]  1995
# 4                                              [Comedy]  1995
# ...                                                 ...   ...
# 9737               [Action, Animation, Comedy, Fantasy]  2017
# 9738                       [Animation, Comedy, Fantasy]  2017
# 9739                                            [Drama]  2017
# 9740                                [Action, Animation]  2018
# 9741                                           [Comedy]  1991
#
# [9742 rows x 4 columns]

# %%
print(movies_df.isnull().sum())
# Out:
# movieId     0
# title       0
# genres      0
# year       13
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
# Merging ratings with movies - use inner because multiple users rated the movies
ratings_movies_df = pd.merge(ratings_df, movies_df, on='movieId', how='inner')

# Merging ratings_movies with tags
ratings_movies_tags_df = pd.merge(ratings_movies_df, tags_df, on=['movieId', 'userId'], how='left')

# Merging ratings_movies_tags with links
data_df = pd.merge(ratings_movies_tags_df, links_df, on='movieId', how='left')
data_df
# Out:
#         userId  movieId  rating  timestamp_x                           title  \
# 0            1        1     4.0    964982703                Toy Story (1995)
# 1            1        3     4.0    964981247         Grumpier Old Men (1995)
# 2            1        6     4.0    964982224                     Heat (1995)
# 3            1       47     5.0    964983815     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0    964982931      Usual Suspects, The (1995)
# ...        ...      ...     ...          ...                             ...
# 102672     610   166534     4.0   1493848402                    Split (2017)
# 102673     610   168248     5.0   1493850091   John Wick: Chapter Two (2017)
# 102674     610   168250     5.0   1494273047                  Get Out (2017)
# 102675     610   168252     5.0   1493846352                    Logan (2017)
# 102676     610   170875     3.0   1493846415  The Fate of the Furious (2017)
#
#                                                    genres  year  \
# 0       [Adventure, Animation, Children, Comedy, Fantasy]  1995
# 1                                       [Comedy, Romance]  1995
# 2                               [Action, Crime, Thriller]  1995
# 3                                     [Mystery, Thriller]  1995
# 4                              [Crime, Mystery, Thriller]  1995
# ...                                                   ...   ...
# 102672                          [Drama, Horror, Thriller]  2017
# 102673                          [Action, Crime, Thriller]  2017
# 102674                                           [Horror]  2017
# 102675                                   [Action, Sci-Fi]  2017
# 102676                   [Action, Crime, Drama, Thriller]  2017
#
#                      tag   timestamp_y   imdbId    tmdbId
# 0                    NaN           NaN   114709     862.0
# 1                    NaN           NaN   113228   15602.0
# 2                    NaN           NaN   113277     949.0
# 3                    NaN           NaN   114369     807.0
# 4                    NaN           NaN   114814     629.0
# ...                  ...           ...      ...       ...
# 102672               NaN           NaN  4972582  381288.0
# 102673  Heroic Bloodshed  1.493844e+09  4425200  324552.0
# 102674               NaN           NaN  5052448  419430.0
# 102675               NaN           NaN  3315342  263115.0
# 102676               NaN           NaN  4630562  337339.0
#
# [102677 rows x 11 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102677 entries, 0 to 102676
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   userId       102677 non-null  int64
#  1   movieId      102677 non-null  int64
#  2   rating       102677 non-null  float64
#  3   timestamp_x  102677 non-null  int64
#  4   title        102677 non-null  object
#  5   genres       102677 non-null  object
#  6   year         102657 non-null  object
#  7   tag          3476 non-null    object
#  8   timestamp_y  3476 non-null    float64
#  9   imdbId       102677 non-null  int64
#  10  tmdbId       102664 non-null  float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 8.6+ MB

# %%
# Filling missing values in 'tag' column with 'Unknown'
data_df['tag'] = data_df['tag'].fillna('Unknown')

# %%
import re

# Function to clean the title by removing the year and exclamation marks
def clean_title(title):
    # Removing year
    title = re.sub(r'\(\d{4}\)', '', title)
    # Removing parentheses
    title = title.replace('()', '')
    # Stripping any extra spaces
    return title.strip()

# Applying cleanig function to 'title' column
data_df['title'] = data_df['title'].apply(clean_title)
data_df
# Out:
#         userId  movieId  rating  timestamp_x                    title  \
# 0            1        1     4.0    964982703                Toy Story
# 1            1        3     4.0    964981247         Grumpier Old Men
# 2            1        6     4.0    964982224                     Heat
# 3            1       47     5.0    964983815     Seven (a.k.a. Se7en)
# 4            1       50     5.0    964982931      Usual Suspects, The
# ...        ...      ...     ...          ...                      ...
# 102672     610   166534     4.0   1493848402                    Split
# 102673     610   168248     5.0   1493850091   John Wick: Chapter Two
# 102674     610   168250     5.0   1494273047                  Get Out
# 102675     610   168252     5.0   1493846352                    Logan
# 102676     610   170875     3.0   1493846415  The Fate of the Furious
#
#                                                    genres  year  \
# 0       [Adventure, Animation, Children, Comedy, Fantasy]  1995
# 1                                       [Comedy, Romance]  1995
# 2                               [Action, Crime, Thriller]  1995
# 3                                     [Mystery, Thriller]  1995
# 4                              [Crime, Mystery, Thriller]  1995
# ...                                                   ...   ...
# 102672                          [Drama, Horror, Thriller]  2017
# 102673                          [Action, Crime, Thriller]  2017
# 102674                                           [Horror]  2017
# 102675                                   [Action, Sci-Fi]  2017
# 102676                   [Action, Crime, Drama, Thriller]  2017
#
#                      tag   timestamp_y   imdbId    tmdbId
# 0                Unknown           NaN   114709     862.0
# 1                Unknown           NaN   113228   15602.0
# 2                Unknown           NaN   113277     949.0
# 3                Unknown           NaN   114369     807.0
# 4                Unknown           NaN   114814     629.0
# ...                  ...           ...      ...       ...
# 102672           Unknown           NaN  4972582  381288.0
# 102673  Heroic Bloodshed  1.493844e+09  4425200  324552.0
# 102674           Unknown           NaN  5052448  419430.0
# 102675           Unknown           NaN  3315342  263115.0
# 102676           Unknown           NaN  4630562  337339.0
#
# [102677 rows x 11 columns]

# %%
# Converting 'timestamp_x' column to actual dates
data_df['timestamp_x'] = pd.to_datetime(data_df['timestamp_x'], unit='s')
data_df.head()
# Out:
#    userId  movieId  rating         timestamp_x                 title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The
#
#                                               genres  year      tag  \
# 0  [Adventure, Animation, Children, Comedy, Fantasy]  1995  Unknown
# 1                                  [Comedy, Romance]  1995  Unknown
# 2                          [Action, Crime, Thriller]  1995  Unknown
# 3                                [Mystery, Thriller]  1995  Unknown
# 4                         [Crime, Mystery, Thriller]  1995  Unknown
#
#    timestamp_y  imdbId   tmdbId
# 0          NaN  114709    862.0
# 1          NaN  113228  15602.0
# 2          NaN  113277    949.0
# 3          NaN  114369    807.0
# 4          NaN  114814    629.0

# %%
# Dropping 'timestamp_y' - It is unnessecary
data_df = data_df.drop(columns=['timestamp_y'])
data_df.head()
# Out:
#    userId  movieId  rating         timestamp_x                 title  \
# 0       1        1     4.0 2000-07-30 18:45:03             Toy Story
# 1       1        3     4.0 2000-07-30 18:20:47      Grumpier Old Men
# 2       1        6     4.0 2000-07-30 18:37:04                  Heat
# 3       1       47     5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en)
# 4       1       50     5.0 2000-07-30 18:48:51   Usual Suspects, The
#
#                                               genres  year      tag  imdbId  \
# 0  [Adventure, Animation, Children, Comedy, Fantasy]  1995  Unknown  114709
# 1                                  [Comedy, Romance]  1995  Unknown  113228
# 2                          [Action, Crime, Thriller]  1995  Unknown  113277
# 3                                [Mystery, Thriller]  1995  Unknown  114369
# 4                         [Crime, Mystery, Thriller]  1995  Unknown  114814
#
#     tmdbId
# 0    862.0
# 1  15602.0
# 2    949.0
# 3    807.0
# 4    629.0

# %%
# Displaying rows where the 'year' column has missing (NaN) values
rows_with_missing_year = data_df[data_df['year'].isnull()]
rows_with_missing_year
# Out:
#        userId  movieId  rating         timestamp_x  \
# 9455       62   176601     5.0 2018-05-08 16:00:52
# 17209     105   147250     5.0 2018-05-13 10:29:14
# 17236     105   171749     5.0 2018-05-13 10:29:25
# 18202     111   171631     1.0 2018-01-31 23:21:49
# 18204     111   171891     3.5 2018-01-31 23:09:59
# 30454     209   140956     3.5 2018-04-23 22:23:59
# 30505     210    40697     4.0 2018-05-25 16:36:31
# 47012     305   140956     4.5 2018-07-31 13:26:17
# 47130     306   149334     3.0 2018-02-11 20:19:32
# 50293     318   171495     5.0 2018-01-24 20:40:06
# 58516     380   140956     3.0 2018-08-13 16:02:38
# 65440     414   167570     4.0 2017-11-24 15:03:56
# 71079     448   143410     2.0 2016-09-18 18:53:22
# 72635     462   162414     5.0 2016-11-07 03:32:11
# 82569     514   140956     3.0 2018-08-11 00:08:39
# 84504     528    40697     0.5 2014-02-07 01:27:47
# 89626     567   156605     4.5 2018-05-02 17:50:48
# 89627     567   156605     4.5 2018-05-02 17:50:48
# 89628     567   156605     4.5 2018-05-02 17:50:48
# 96918     599   171495     4.0 2018-02-20 08:55:12
#
#                                                    title  \
# 9455                                        Black Mirror
# 17209  The Adventures of Sherlock Holmes and Doctor W...
# 17236                  Death Note: Desu nôto (2006–2007)
# 18202                            Maria Bamford: Old Baby
# 18204                                  Generation Iron 2
# 30454                                   Ready Player One
# 30505                                          Babylon 5
# 47012                                   Ready Player One
# 47130                                  Nocturnal Animals
# 50293                                             Cosmos
# 58516                                   Ready Player One
# 65440                                             The OA
# 71079                                         Hyena Road
# 72635                                          Moonlight
# 82569                                   Ready Player One
# 84504                                          Babylon 5
# 89626                                           Paterson
# 89627                                           Paterson
# 89628                                           Paterson
# 96918                                             Cosmos
#
#                            genres year          tag   imdbId    tmdbId
# 9455         [(no genres listed)]  NaN      Unknown  2492564  452830.0
# 17209        [(no genres listed)]  NaN      Unknown   229922  127605.0
# 17236        [(no genres listed)]  NaN      Unknown   877057  419787.0
# 18202        [(no genres listed)]  NaN      Unknown  6264596  455601.0
# 18204        [(no genres listed)]  NaN      Unknown  6263642  447818.0
# 30454  [Action, Sci-Fi, Thriller]  NaN      Unknown  1677720  333339.0
# 30505                    [Sci-Fi]  NaN      Unknown   105946       NaN
# 47012  [Action, Sci-Fi, Thriller]  NaN      Unknown  1677720  333339.0
# 47130           [Drama, Thriller]  NaN      Unknown  4550098  340666.0
# 50293        [(no genres listed)]  NaN      Unknown    81846  409926.0
# 58516  [Action, Sci-Fi, Thriller]  NaN      Unknown  1677720  333339.0
# 65440        [(no genres listed)]  NaN      Unknown  4635282  432192.0
# 71079        [(no genres listed)]  NaN      Unknown  4034452  316042.0
# 72635                     [Drama]  NaN      Unknown  4975722  376867.0
# 82569  [Action, Sci-Fi, Thriller]  NaN      Unknown  1677720  333339.0
# 84504                    [Sci-Fi]  NaN      Unknown   105946       NaN
# 89626        [(no genres listed)]  NaN       quirky  5247022  370755.0
# 89627        [(no genres listed)]  NaN        sweet  5247022  370755.0
# 89628        [(no genres listed)]  NaN  understated  5247022  370755.0
# 96918        [(no genres listed)]  NaN      Unknown    81846  409926.0

# %%
# Filling in missing ovie years - Dictionary with movieId as key and the correct year as value
year_updates = {
    176601: 2011, 147250: 1984, 171749: 2006, 171631: 2017, 171891: 2017, 140956: 2018, 40697: 1994, 149334: 2016,
    171495: 2016, 167570: 2016, 143410: 2015, 162414: 2016, 156605: 2016}

# Fill in missing years using
for movie_id, correct_year in year_updates.items():
    data_df.loc[data_df['movieId'] == movie_id, 'year'] = correct_year

data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102677 entries, 0 to 102676
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   userId       102677 non-null  int64
#  1   movieId      102677 non-null  int64
#  2   rating       102677 non-null  float64
#  3   timestamp_x  102677 non-null  datetime64[ns]
#  4   title        102677 non-null  object
#  5   genres       102677 non-null  object
#  6   year         102677 non-null  object
#  7   tag          102677 non-null  object
#  8   imdbId       102677 non-null  int64
#  9   tmdbId       102664 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 7.8+ MB

# %%
# 'year' column to integer
data_df['year'] = data_df['year'].astype(int)
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102677 entries, 0 to 102676
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   userId       102677 non-null  int64
#  1   movieId      102677 non-null  int64
#  2   rating       102677 non-null  float64
#  3   timestamp_x  102677 non-null  datetime64[ns]
#  4   title        102677 non-null  object
#  5   genres       102677 non-null  object
#  6   year         102677 non-null  int64
#  7   tag          102677 non-null  object
#  8   imdbId       102677 non-null  int64
#  9   tmdbId       102664 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 7.8+ MB

# %%
print(data_df.isnull().sum())
# Out:
# userId          0
# movieId         0
# rating          0
# timestamp_x     0
# title           0
# genres          0
# year            0
# tag             0
# imdbId          0
# tmdbId         13
# dtype: int64

# %%
# Count of total user ratings per movie - Grouping by 'movieId' 
ratings_count = data_df.groupby('movieId').size().reset_index(name='number_of_ratings')

# Merging the ratings count
data_df = pd.merge(data_df, ratings_count, on='movieId', how='left')
data_df
# Out:
#         userId  movieId  rating         timestamp_x                    title  \
# 0            1        1     4.0 2000-07-30 18:45:03                Toy Story
# 1            1        3     4.0 2000-07-30 18:20:47         Grumpier Old Men
# 2            1        6     4.0 2000-07-30 18:37:04                     Heat
# 3            1       47     5.0 2000-07-30 19:03:35     Seven (a.k.a. Se7en)
# 4            1       50     5.0 2000-07-30 18:48:51      Usual Suspects, The
# ...        ...      ...     ...                 ...                      ...
# 102672     610   166534     4.0 2017-05-03 21:53:22                    Split
# 102673     610   168248     5.0 2017-05-03 22:21:31   John Wick: Chapter Two
# 102674     610   168250     5.0 2017-05-08 19:50:47                  Get Out
# 102675     610   168252     5.0 2017-05-03 21:19:12                    Logan
# 102676     610   170875     3.0 2017-05-03 21:20:15  The Fate of the Furious
#
#                                                    genres  year  \
# 0       [Adventure, Animation, Children, Comedy, Fantasy]  1995
# 1                                       [Comedy, Romance]  1995
# 2                               [Action, Crime, Thriller]  1995
# 3                                     [Mystery, Thriller]  1995
# 4                              [Crime, Mystery, Thriller]  1995
# ...                                                   ...   ...
# 102672                          [Drama, Horror, Thriller]  2017
# 102673                          [Action, Crime, Thriller]  2017
# 102674                                           [Horror]  2017
# 102675                                   [Action, Sci-Fi]  2017
# 102676                   [Action, Crime, Drama, Thriller]  2017
#
#                      tag   imdbId    tmdbId  number_of_ratings
# 0                Unknown   114709     862.0                215
# 1                Unknown   113228   15602.0                 53
# 2                Unknown   113277     949.0                102
# 3                Unknown   114369     807.0                204
# 4                Unknown   114814     629.0                208
# ...                  ...      ...       ...                ...
# 102672           Unknown  4972582  381288.0                  6
# 102673  Heroic Bloodshed  4425200  324552.0                 13
# 102674           Unknown  5052448  419430.0                 15
# 102675           Unknown  3315342  263115.0                 29
# 102676           Unknown  4630562  337339.0                  3
#
# [102677 rows x 11 columns]

# %%
# Calculate the mean (average) rating for each movie - Group by 'movieId'
average_ratings = data_df.groupby('movieId')['rating'].mean().round(1).reset_index(name='average_rating')

# Merge the average rating back into the original dataframe
data_df = pd.merge(data_df, average_ratings, on='movieId', how='left')
data_df
# Out:
#         userId  movieId  rating         timestamp_x                    title  \
# 0            1        1     4.0 2000-07-30 18:45:03                Toy Story
# 1            1        3     4.0 2000-07-30 18:20:47         Grumpier Old Men
# 2            1        6     4.0 2000-07-30 18:37:04                     Heat
# 3            1       47     5.0 2000-07-30 19:03:35     Seven (a.k.a. Se7en)
# 4            1       50     5.0 2000-07-30 18:48:51      Usual Suspects, The
# ...        ...      ...     ...                 ...                      ...
# 102672     610   166534     4.0 2017-05-03 21:53:22                    Split
# 102673     610   168248     5.0 2017-05-03 22:21:31   John Wick: Chapter Two
# 102674     610   168250     5.0 2017-05-08 19:50:47                  Get Out
# 102675     610   168252     5.0 2017-05-03 21:19:12                    Logan
# 102676     610   170875     3.0 2017-05-03 21:20:15  The Fate of the Furious
#
#                                                    genres  year  \
# 0       [Adventure, Animation, Children, Comedy, Fantasy]  1995
# 1                                       [Comedy, Romance]  1995
# 2                               [Action, Crime, Thriller]  1995
# 3                                     [Mystery, Thriller]  1995
# 4                              [Crime, Mystery, Thriller]  1995
# ...                                                   ...   ...
# 102672                          [Drama, Horror, Thriller]  2017
# 102673                          [Action, Crime, Thriller]  2017
# 102674                                           [Horror]  2017
# 102675                                   [Action, Sci-Fi]  2017
# 102676                   [Action, Crime, Drama, Thriller]  2017
#
#                      tag   imdbId    tmdbId  number_of_ratings  average_rating
# 0                Unknown   114709     862.0                215             3.9
# 1                Unknown   113228   15602.0                 53             3.2
# 2                Unknown   113277     949.0                102             3.9
# 3                Unknown   114369     807.0                204             4.0
# 4                Unknown   114814     629.0                208             4.3
# ...                  ...      ...       ...                ...             ...
# 102672           Unknown  4972582  381288.0                  6             3.3
# 102673  Heroic Bloodshed  4425200  324552.0                 13             4.3
# 102674           Unknown  5052448  419430.0                 15             3.6
# 102675           Unknown  3315342  263115.0                 29             4.2
# 102676           Unknown  4630562  337339.0                  3             2.3
#
# [102677 rows x 12 columns]

# %%
# Renaming columns
data_df = data_df.rename(columns={'timestamp_x': 'timestamp'})

#Drop TMBD
data_df = data_df.dropna(axis=1)
data_df
# Out:
#         userId  movieId  rating           timestamp                    title  \
# 0            1        1     4.0 2000-07-30 18:45:03                Toy Story
# 1            1        3     4.0 2000-07-30 18:20:47         Grumpier Old Men
# 2            1        6     4.0 2000-07-30 18:37:04                     Heat
# 3            1       47     5.0 2000-07-30 19:03:35     Seven (a.k.a. Se7en)
# 4            1       50     5.0 2000-07-30 18:48:51      Usual Suspects, The
# ...        ...      ...     ...                 ...                      ...
# 102672     610   166534     4.0 2017-05-03 21:53:22                    Split
# 102673     610   168248     5.0 2017-05-03 22:21:31   John Wick: Chapter Two
# 102674     610   168250     5.0 2017-05-08 19:50:47                  Get Out
# 102675     610   168252     5.0 2017-05-03 21:19:12                    Logan
# 102676     610   170875     3.0 2017-05-03 21:20:15  The Fate of the Furious
#
#                                                    genres  year  \
# 0       [Adventure, Animation, Children, Comedy, Fantasy]  1995
# 1                                       [Comedy, Romance]  1995
# 2                               [Action, Crime, Thriller]  1995
# 3                                     [Mystery, Thriller]  1995
# 4                              [Crime, Mystery, Thriller]  1995
# ...                                                   ...   ...
# 102672                          [Drama, Horror, Thriller]  2017
# 102673                          [Action, Crime, Thriller]  2017
# 102674                                           [Horror]  2017
# 102675                                   [Action, Sci-Fi]  2017
# 102676                   [Action, Crime, Drama, Thriller]  2017
#
#                      tag   imdbId  number_of_ratings  average_rating
# 0                Unknown   114709                215             3.9
# 1                Unknown   113228                 53             3.2
# 2                Unknown   113277                102             3.9
# 3                Unknown   114369                204             4.0
# 4                Unknown   114814                208             4.3
# ...                  ...      ...                ...             ...
# 102672           Unknown  4972582                  6             3.3
# 102673  Heroic Bloodshed  4425200                 13             4.3
# 102674           Unknown  5052448                 15             3.6
# 102675           Unknown  3315342                 29             4.2
# 102676           Unknown  4630562                  3             2.3
#
# [102677 rows x 11 columns]

# %% [markdown]
# ## Plotting

# %%
# Average Rating User Has Given to Movies
average_rating_user = data_df.groupby('userId')['rating'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(average_rating_user, bins=30, kde=True, color='green')
plt.title('Distribution of Average Rating per User')
plt.xlabel('Average Rating')
plt.ylabel('Users')
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
# Correlation Between Number of Ratings and Average Rating. Exploring whether movies with more ratings tend to 
# have higher or lower average ratings.

ratings_per_movie = data_df.groupby('movieId')['rating'].count()
average_rating_per_movie = data_df.groupby('movieId')['rating'].mean()

plt.figure(figsize=(8, 6))
sns.scatterplot(x=ratings_per_movie, y=average_rating_per_movie, alpha=0.5, color='green')
plt.title('Correlation Between Number of Ratings and Average Rating')
plt.xlabel('Number of Ratings')
plt.ylabel('Average Rating')
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
# Average number of ratings per user
ratings_per_user = data_df.groupby('userId')['rating'].count()
average_ratings_per_user = ratings_per_user.mean()

plt.figure(figsize=(10, 6))
sns.histplot(ratings_per_user, bins=30, color='purple')
plt.axvline(average_ratings_per_user, color='red', linestyle='--')
plt.title(f'Average Number of Ratings per User: {average_ratings_per_user:.2f}')
plt.xlabel('Number of Ratings')
plt.ylabel('User')
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
# Multiple Genres per Movie
data_df['num_genres'] = data_df['genres'].apply(lambda x: len(eval('x')))

plt.figure(figsize=(12, 6))
sns.histplot(data_df['num_genres'], bins=10, color='green')
plt.title('Distribution of Number of Genres Per Movie')
plt.xlabel('Number of Genres')
plt.ylabel('Movie')
plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()

# %%
# Ratings per Genre: Distribution of ratings across different genres
genre_ratings = data_df.copy()
genre_ratings['genres'] = genre_ratings['genres'].apply(lambda x: eval('x'))
genre_ratings = genre_ratings.explode('genres')

plt.figure(figsize=(12, 8))
sns.boxplot(x='genres', y='rating', data=genre_ratings, palette='viridis')
plt.title('Ratings per Genre')
plt.xlabel('Genre')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/h2/7np79zrx3xj5tj51tm9hq1zw0000gn/T/ipykernel_91587/3593432989.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='genres', y='rating', data=genre_ratings, palette='viridis')

# %%
# Splitting genres
genre_ratings = data_df.copy()
genre_ratings['genres'] = genre_ratings['genres'].apply(lambda x: eval('x'))
genre_ratings = genre_ratings.explode('genres')

# Calculating the average rating per genre
avg_rat_genre = genre_ratings.groupby('genres')['rating'].mean().reset_index()
avg_rat_genre.columns = ['genre', 'avg_rat_genre']
avg_rat_genre['avg_rat_genre'] = avg_rat_genre['avg_rat_genre'].round(2)

# Counting the number of movies per genre
movies_per_genre = genre_ratings.groupby('genres')['movieId'].nunique().reset_index()
movies_per_genre.columns = ['genre', 'num_movies_per_genre']

# Counting the number of users per genre
users_per_genre = genre_ratings.groupby('genres')['userId'].nunique().reset_index()
users_per_genre.columns = ['genre', 'num_users_per_genre']

# Merging into one DataFrame
genre_analysis = pd.merge(avg_rat_genre, movies_per_genre, on='genre')
genre_analysis = pd.merge(genre_analysis, users_per_genre, on='genre')

# Calculating the percentage of movies per genre
total_movies = genre_ratings['movieId'].nunique()
genre_analysis['%_total_movies'] = (genre_analysis['num_movies_per_genre'] / total_movies * 100).round(1)
genre_analysis
# Out:
#                  genre  avg_rat_genre  num_movies_per_genre  \
# 0   (no genres listed)           3.53                    34
# 1               Action           3.46                  1828
# 2            Adventure           3.52                  1262
# 3            Animation           3.64                   610
# 4             Children           3.42                   664
# 5               Comedy           3.40                  3753
# 6                Crime           3.69                  1196
# 7          Documentary           3.81                   438
# 8                Drama           3.67                  4349
# 9              Fantasy           3.50                   778
# 10           Film-Noir           3.92                    85
# 11              Horror           3.27                   977
# 12                IMAX           3.63                   158
# 13             Musical           3.57                   333
# 14             Mystery           3.65                   573
# 15             Romance           3.51                  1591
# 16              Sci-Fi           3.47                   980
# 17            Thriller           3.52                  1889
# 18                 War           3.81                   381
# 19             Western           3.61                   167
#
#     num_users_per_genre  %_total_movies
# 0                    26             0.3
# 1                   608            18.8
# 2                   606            13.0
# 3                   527             6.3
# 4                   559             6.8
# 5                   609            38.6
# 6                   603            12.3
# 7                   223             4.5
# 8                   610            44.7
# 9                   583             8.0
# 10                  239             0.9
# 11                  535            10.0
# 12                  458             1.6
# 13                  470             3.4
# 14                  580             5.9
# 15                  606            16.4
# 16                  605            10.1
# 17                  609            19.4
# 18                  551             3.9
# 19                  420             1.7

# %%
# Average Rating per Genre
sns.barplot(x='avg_rat_genre', y='genre', data=genre_analysis, palette='Blues_d')
plt.title('Average Rating per Genre')
plt.xlabel('Average Rating')
plt.ylabel('Genre');
# Out:
# /var/folders/h2/7np79zrx3xj5tj51tm9hq1zw0000gn/T/ipykernel_91587/617182692.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='avg_rat_genre', y='genre', data=genre_analysis, palette='Blues_d')

# %%
# Number of Movies per Genre
sns.barplot(x='num_movies_per_genre', y='genre', data=genre_analysis, palette='Greens_d')
plt.title('Number of Movies per Genre')
plt.xlabel('Number of Movies')
plt.ylabel('Genre')
# Out:
# /var/folders/h2/7np79zrx3xj5tj51tm9hq1zw0000gn/T/ipykernel_91587/3404618927.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='num_movies_per_genre', y='genre', data=genre_analysis, palette='Greens_d')
# Text(0, 0.5, 'Genre')

# %%
# Number of Users per Genre
sns.barplot(x='num_users_per_genre', y='genre', data=genre_analysis, palette='Oranges_d')
plt.title('Number of Users per Genre')
plt.xlabel('Number of Users')
plt.ylabel('Genre')
# Out:
# /var/folders/h2/7np79zrx3xj5tj51tm9hq1zw0000gn/T/ipykernel_91587/4179274834.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='num_users_per_genre', y='genre', data=genre_analysis, palette='Oranges_d')
# Text(0, 0.5, 'Genre')

# %%
from wordcloud import WordCloud

# Word cloud for movie titles
title_wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(data_df['title']))

plt.figure(figsize=(14, 8))
plt.imshow(title_wordcloud, interpolation='bilinear')
plt.title('Word Cloud of Movie Titles')
plt.axis('off')
plt.show()

# %%
# Genre-movie matrix - Correlations between genres: For example, are users who like “Action” movies also likely 
# to enjoy “Adventure” or “Thriller” genres? Helpful in making cross-genre recommendations?
genre_movie_matrix = genre_ratings.pivot_table(index='movieId', columns='genres', values='rating', aggfunc='mean').fillna(0)

# Calculating correlation between genres
genre_correlation = genre_movie_matrix.corr()

# Plotting correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(genre_correlation, cmap='coolwarm', cbar=True)
plt.title('Genre Correlation Matrix')
plt.xlabel('Genre')
plt.ylabel('Genre')
plt.show()

# %%
# User-movie rating matrix: Calculate the similarity between users based on their rating patterns. 
# Useful for collaborative filtering-based recommendation systems.
user_movie_matrix = data_df.pivot_table(index='userId', columns='movieId', values='rating')

# Pearson correlation between users
user_similarity = user_movie_matrix.corr(method='pearson')

# Plotting similarity matrix
plt.figure(figsize=(12, 10))
sns.heatmap(user_similarity, cmap='coolwarm', cbar=True)
plt.title('User-User Similarity Matrix')
plt.xlabel('User ID')
plt.ylabel('User ID')
plt.show()

# %% [markdown]
# - collaborative: users with similar genre preferences can be grouped together,
# - content-based filtering: recommendations are made based on the user’s historical ratings within certain genres

# %% [markdown]
# # IMDB Data Merge

# %%
# IMDB File path
file_path = '/Users/timjamboula/code/m-r-c-l/Movie-Recommendation-Engine/raw_data/ml-latest-small/TMDB_all_movies.csv'  # Adjust the file name if necessary
imdb_df = pd.read_csv(file_path)

imdb_df
# Out:
#              id                             title  vote_average  vote_count  \
# 0             2                             Ariel         7.100       327.0
# 1             3               Shadows in Paradise         7.300       369.0
# 2             5                        Four Rooms         5.800      2593.0
# 3             6                    Judgment Night         6.483       329.0
# 4             8  Life in Loops (A Megacities RMX)         7.500        27.0
# ...         ...                               ...           ...         ...
# 979802  1342437                    Dead Leaf Moth         0.000         0.0
# 979803  1342438                          The Farm         0.000         0.0
# 979804  1342439                            Hickey         0.000         0.0
# 979805  2662126                               NaN           NaN         NaN
# 979806  5180730                               NaN           NaN         NaN
#
#           status release_date     revenue  runtime      budget    imdb_id  \
# 0       Released   1988-10-21         0.0     73.0         0.0  tt0094675
# 1       Released   1986-10-17         0.0     74.0         0.0  tt0092149
# 2       Released   1995-12-09   4257354.0     98.0   4000000.0  tt0113101
# 3       Released   1993-10-15  12136938.0    109.0  21000000.0  tt0107286
# 4       Released   2006-01-01         0.0     80.0     42000.0  tt0825671
# ...          ...          ...         ...      ...         ...        ...
# 979802  Released          NaN         0.0      0.0         0.0        NaN
# 979803  Released          NaN         0.0     19.0         0.0        NaN
# 979804  Released          NaN         0.0     19.0         0.0        NaN
# 979805       NaN          NaN         NaN      NaN         NaN        NaN
# 979806       NaN          NaN         NaN      NaN         NaN        NaN
#
#         ...      production_countries                        spoken_languages  \
# 0       ...                   Finland                                   suomi
# 1       ...                   Finland                 suomi, English, svenska
# 2       ...  United States of America                                 English
# 3       ...  United States of America                                 English
# 4       ...                   Austria  English, हिन्दी, 日本語, Pусский, Español
# ...     ...                       ...                                     ...
# 979802  ...                       NaN                                     NaN
# 979803  ...                       NaN                                     NaN
# 979804  ...                       NaN                                     NaN
# 979805  ...                       NaN                                     NaN
# 979806  ...                       NaN                                     NaN
#
#                                                      cast  \
# 0       Eino Kuusela, Timo Harakka, Sirkka Rautiainen,...
# 1       Kati Outinen, Ulla Kuosmanen, Jaakko Talaskivi...
# 2       Jennifer Beals, Sammi Davis, Ione Skye, Paul C...
# 3       Kathleen Perkins, Relioues Webb, Emilio Esteve...
# 4                                                     NaN
# ...                                                   ...
# 979802                                                NaN
# 979803                                                NaN
# 979804                                                NaN
# 979805  Johannes Allmayer, Jules Waringo, Vicky Krieps...
# 979806  Hailee Steinfeld, Tim Martin Gleason, Holland ...
#
#                                                  director  \
# 0                                          Aki Kaurismäki
# 1                                          Aki Kaurismäki
# 2       Allison Anders, Quentin Tarantino, Alexandre R...
# 3                                         Stephen Hopkins
# 4                                            Timo Novotny
# ...                                                   ...
# 979802                                                NaN
# 979803                                                NaN
# 979804                                                NaN
# 979805                               Florian Gallenberger
# 979806                                      Travis Knight
#
#                                   director_of_photography  \
# 0                                           Timo Salminen
# 1                                           Timo Salminen
# 2       Andrzej Sekula, Rodrigo García, Guillermo Nava...
# 3                                              Peter Levy
# 4                                         Wolfgang Thaler
# ...                                                   ...
# 979802                                                NaN
# 979803                                                NaN
# 979804                                                NaN
# 979805                                       Kolja Brandt
# 979806                                    Enrique Chediak
#
#                                                   writers  \
# 0                                          Aki Kaurismäki
# 1                                          Aki Kaurismäki
# 2       Alexandre Rockwell, Allison Anders, Quentin Ta...
# 3                           Jere Cunningham, Lewis Colick
# 4                         Michael Glawogger, Timo Novotny
# ...                                                   ...
# 979802                                                NaN
# 979803                                                NaN
# 979804                                                NaN
# 979805  Florian Gallenberger, Torsten Wenzel, Tom Kinn...
# 979806                   Christina Hodson, Shoji Kawamori
#
#                                                 producers      music_composer  \
# 0                                          Aki Kaurismäki                 NaN
# 1                                         Mika Kaurismäki                 NaN
# 2       Alexandre Rockwell, Quentin Tarantino, Lawrenc...  Combustible Edison
# 3                   Marilyn Vance, Lloyd Segan, Gene Levy      Alan Silvestri
# 4                          Ulrich Gehmacher, Timo Novotny                 NaN
# ...                                                   ...                 ...
# 979802                                                NaN                 NaN
# 979803                                                NaN                 NaN
# 979804                                                NaN                 NaN
# 979805                   Nicolas Steil, Benjamin Herrmann                 NaN
# 979806  Chris Brigham, Stephen Davis, Don Murphy, Bria...    Dario Marianelli
#
#        imdb_rating imdb_votes
# 0              7.4     8635.0
# 1              7.5     7371.0
# 2              6.7   111991.0
# 3              6.6    19114.0
# 4              8.2      283.0
# ...            ...        ...
# 979802         NaN        NaN
# 979803         NaN        NaN
# 979804         NaN        NaN
# 979805         NaN        NaN
# 979806         NaN        NaN
#
# [979807 rows x 27 columns]

# %%
# Cleaning the imdb_id by removing all variations of 'tt', 'tt0', 'tt00', etc.
def clean_imdb_id(imdb_id):
    # Converting the value to string
    imdb_id_str = str(imdb_id)
    cleaned_id = imdb_id.lstrip('tt0')
    cleaned_id = imdb_id.lstrip('tt00')
    cleaned_id = imdb_id.lstrip('tt000')
    cleaned_id = imdb_id.lstrip('tt0000')
    cleaned_id = imdb_id.lstrip('tt00000')
    cleaned_id = imdb_id.lstrip('tt000000')
    return cleaned_id

# imdb_id column to string
imdb_df['imdb_id'] = imdb_df['imdb_id'].astype(str)

# Apply
imdb_df['imdb_cleaned'] = imdb_df['imdb_id'].apply(clean_imdb_id)
imdb_df
# Out:
#              id                             title  vote_average  vote_count  \
# 0             2                             Ariel         7.100       327.0
# 1             3               Shadows in Paradise         7.300       369.0
# 2             5                        Four Rooms         5.800      2593.0
# 3             6                    Judgment Night         6.483       329.0
# 4             8  Life in Loops (A Megacities RMX)         7.500        27.0
# ...         ...                               ...           ...         ...
# 979802  1342437                    Dead Leaf Moth         0.000         0.0
# 979803  1342438                          The Farm         0.000         0.0
# 979804  1342439                            Hickey         0.000         0.0
# 979805  2662126                               NaN           NaN         NaN
# 979806  5180730                               NaN           NaN         NaN
#
#           status release_date     revenue  runtime      budget    imdb_id  \
# 0       Released   1988-10-21         0.0     73.0         0.0  tt0094675
# 1       Released   1986-10-17         0.0     74.0         0.0  tt0092149
# 2       Released   1995-12-09   4257354.0     98.0   4000000.0  tt0113101
# 3       Released   1993-10-15  12136938.0    109.0  21000000.0  tt0107286
# 4       Released   2006-01-01         0.0     80.0     42000.0  tt0825671
# ...          ...          ...         ...      ...         ...        ...
# 979802  Released          NaN         0.0      0.0         0.0        nan
# 979803  Released          NaN         0.0     19.0         0.0        nan
# 979804  Released          NaN         0.0     19.0         0.0        nan
# 979805       NaN          NaN         NaN      NaN         NaN        nan
# 979806       NaN          NaN         NaN      NaN         NaN        nan
#
#         ...                        spoken_languages  \
# 0       ...                                   suomi
# 1       ...                 suomi, English, svenska
# 2       ...                                 English
# 3       ...                                 English
# 4       ...  English, हिन्दी, 日本語, Pусский, Español
# ...     ...                                     ...
# 979802  ...                                     NaN
# 979803  ...                                     NaN
# 979804  ...                                     NaN
# 979805  ...                                     NaN
# 979806  ...                                     NaN
#
#                                                      cast  \
# 0       Eino Kuusela, Timo Harakka, Sirkka Rautiainen,...
# 1       Kati Outinen, Ulla Kuosmanen, Jaakko Talaskivi...
# 2       Jennifer Beals, Sammi Davis, Ione Skye, Paul C...
# 3       Kathleen Perkins, Relioues Webb, Emilio Esteve...
# 4                                                     NaN
# ...                                                   ...
# 979802                                                NaN
# 979803                                                NaN
# 979804                                                NaN
# 979805  Johannes Allmayer, Jules Waringo, Vicky Krieps...
# 979806  Hailee Steinfeld, Tim Martin Gleason, Holland ...
#
#                                                  director  \
# 0                                          Aki Kaurismäki
# 1                                          Aki Kaurismäki
# 2       Allison Anders, Quentin Tarantino, Alexandre R...
# 3                                         Stephen Hopkins
# 4                                            Timo Novotny
# ...                                                   ...
# 979802                                                NaN
# 979803                                                NaN
# 979804                                                NaN
# 979805                               Florian Gallenberger
# 979806                                      Travis Knight
#
#                                   director_of_photography  \
# 0                                           Timo Salminen
# 1                                           Timo Salminen
# 2       Andrzej Sekula, Rodrigo García, Guillermo Nava...
# 3                                              Peter Levy
# 4                                         Wolfgang Thaler
# ...                                                   ...
# 979802                                                NaN
# 979803                                                NaN
# 979804                                                NaN
# 979805                                       Kolja Brandt
# 979806                                    Enrique Chediak
#
#                                                   writers  \
# 0                                          Aki Kaurismäki
# 1                                          Aki Kaurismäki
# 2       Alexandre Rockwell, Allison Anders, Quentin Ta...
# 3                           Jere Cunningham, Lewis Colick
# 4                         Michael Glawogger, Timo Novotny
# ...                                                   ...
# 979802                                                NaN
# 979803                                                NaN
# 979804                                                NaN
# 979805  Florian Gallenberger, Torsten Wenzel, Tom Kinn...
# 979806                   Christina Hodson, Shoji Kawamori
#
#                                                 producers      music_composer  \
# 0                                          Aki Kaurismäki                 NaN
# 1                                         Mika Kaurismäki                 NaN
# 2       Alexandre Rockwell, Quentin Tarantino, Lawrenc...  Combustible Edison
# 3                   Marilyn Vance, Lloyd Segan, Gene Levy      Alan Silvestri
# 4                          Ulrich Gehmacher, Timo Novotny                 NaN
# ...                                                   ...                 ...
# 979802                                                NaN                 NaN
# 979803                                                NaN                 NaN
# 979804                                                NaN                 NaN
# 979805                   Nicolas Steil, Benjamin Herrmann                 NaN
# 979806  Chris Brigham, Stephen Davis, Don Murphy, Bria...    Dario Marianelli
#
#        imdb_rating imdb_votes imdb_cleaned
# 0              7.4     8635.0        94675
# 1              7.5     7371.0        92149
# 2              6.7   111991.0       113101
# 3              6.6    19114.0       107286
# 4              8.2      283.0       825671
# ...            ...        ...          ...
# 979802         NaN        NaN          nan
# 979803         NaN        NaN          nan
# 979804         NaN        NaN          nan
# 979805         NaN        NaN          nan
# 979806         NaN        NaN          nan
#
# [979807 rows x 28 columns]

# %%
# Dropping 'timestamp_y' - It is unnessecary
imdb_df = imdb_df.drop(columns=["id"])
imdb_df = imdb_df.drop(columns=["status"])
imdb_df = imdb_df.drop(columns=["release_date"])
imdb_df = imdb_df.drop(columns=["original_language"])
imdb_df = imdb_df.drop(columns=["original_title"])
imdb_df = imdb_df.drop(columns=["production_companies"])
imdb_df = imdb_df.drop(columns=["production_countries"])
imdb_df = imdb_df.drop(columns=["director_of_photography"])
imdb_df = imdb_df.drop(columns=["writers"])
imdb_df = imdb_df.drop(columns=["producers"])
imdb_df = imdb_df.drop(columns=["music_composer"])
imdb_df.head()
# Out:
#                               title  vote_average  vote_count     revenue  \
# 0                             Ariel         7.100       327.0         0.0
# 1               Shadows in Paradise         7.300       369.0         0.0
# 2                        Four Rooms         5.800      2593.0   4257354.0
# 3                    Judgment Night         6.483       329.0  12136938.0
# 4  Life in Loops (A Megacities RMX)         7.500        27.0         0.0
#
#    runtime      budget    imdb_id  \
# 0     73.0         0.0  tt0094675
# 1     74.0         0.0  tt0092149
# 2     98.0   4000000.0  tt0113101
# 3    109.0  21000000.0  tt0107286
# 4     80.0     42000.0  tt0825671
#
#                                             overview  popularity  \
# 0  After the coal mine he works at closes and his...      31.143
# 1  Nikander, a rubbish collector and would-be ent...      16.287
# 2  It's Ted the Bellhop's first night on the job....      19.383
# 3  Four young friends, while taking a shortcut en...      13.344
# 4  Timo Novotny labels his new project an experim...       3.203
#
#                                              tagline  \
# 0                                                NaN
# 1                                                NaN
# 2  Twelve outrageous guests. Four scandalous requ...
# 3     Don't move. Don't whisper. Don't even breathe.
# 4                                A Megacities remix.
#
#                           genres                        spoken_languages  \
# 0  Comedy, Drama, Romance, Crime                                   suomi
# 1         Comedy, Drama, Romance                 suomi, English, svenska
# 2                         Comedy                                 English
# 3        Action, Crime, Thriller                                 English
# 4                    Documentary  English, हिन्दी, 日本語, Pусский, Español
#
#                                                 cast  \
# 0  Eino Kuusela, Timo Harakka, Sirkka Rautiainen,...
# 1  Kati Outinen, Ulla Kuosmanen, Jaakko Talaskivi...
# 2  Jennifer Beals, Sammi Davis, Ione Skye, Paul C...
# 3  Kathleen Perkins, Relioues Webb, Emilio Esteve...
# 4                                                NaN
#
#                                             director  imdb_rating  imdb_votes  \
# 0                                     Aki Kaurismäki          7.4      8635.0
# 1                                     Aki Kaurismäki          7.5      7371.0
# 2  Allison Anders, Quentin Tarantino, Alexandre R...          6.7    111991.0
# 3                                    Stephen Hopkins          6.6     19114.0
# 4                                       Timo Novotny          8.2       283.0
#
#   imdb_cleaned
# 0        94675
# 1        92149
# 2       113101
# 3       107286
# 4       825671

# %%
imdb_df = imdb_df.rename(columns={'imdb_cleaned': 'imdbId'})
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979807 entries, 0 to 979806
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   title             979798 non-null  object
#  1   vote_average      979805 non-null  float64
#  2   vote_count        979805 non-null  float64
#  3   revenue           979805 non-null  float64
#  4   runtime           979805 non-null  float64
#  5   budget            979805 non-null  float64
#  6   imdb_id           979807 non-null  object
#  7   overview          811782 non-null  object
#  8   popularity        979805 non-null  float64
#  9   tagline           145296 non-null  object
#  10  genres            696352 non-null  object
#  11  spoken_languages  605146 non-null  object
#  12  cast              656546 non-null  object
#  13  director          806089 non-null  object
#  14  imdb_rating       420663 non-null  float64
#  15  imdb_votes        420663 non-null  float64
#  16  imdbId            979807 non-null  object
# dtypes: float64(8), object(9)
# memory usage: 127.1+ MB

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102677 entries, 0 to 102676
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   userId              102677 non-null  int64
#  1   movieId             102677 non-null  int64
#  2   user_rating         102677 non-null  float64
#  3   user_rating_time    102677 non-null  datetime64[ns]
#  4   title               102677 non-null  object
#  5   genres              102677 non-null  object
#  6   release_year        102677 non-null  int64
#  7   tag                 102677 non-null  object
#  8   imdbId              102677 non-null  object
#  9   total_user_ratings  102677 non-null  int64
#  10  average_rating      102677 non-null  float64
#  11  num_genres          102677 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(4)
# memory usage: 9.4+ MB

# %%
# Ensure that both 'imdbId' columns are of the same data type (string in this case)
data_df['imdbId'] = data_df['imdbId'].astype(str)
imdb_df['imdbId'] = imdb_df['imdbId'].astype(str)

# Perform the merge
imdb_merged_data = pd.merge(data_df, imdb_df, on='imdbId', how='left')
imdb_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102688 entries, 0 to 102687
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   userId              102688 non-null  int64
#  1   movieId             102688 non-null  int64
#  2   user_rating         102688 non-null  float64
#  3   user_rating_time    102688 non-null  datetime64[ns]
#  4   title_x             102688 non-null  object
#  5   genres_x            102688 non-null  object
#  6   release_year        102688 non-null  int64
#  7   tag                 102688 non-null  object
#  8   imdbId              102688 non-null  object
#  9   total_user_ratings  102688 non-null  int64
#  10  average_rating      102688 non-null  float64
#  11  num_genres          102688 non-null  int64
#  12  title_y             102439 non-null  object
#  13  vote_average        102439 non-null  float64
#  14  vote_count          102439 non-null  float64
#  15  revenue             102439 non-null  float64
#  16  runtime             102439 non-null  float64
#  17  budget              102439 non-null  float64
#  18  imdb_id             102439 non-null  object
#  19  overview            102429 non-null  object
#  20  popularity          102439 non-null  float64
#  21  tagline             98914 non-null   object
#  22  genres_y            102433 non-null  object
#  23  spoken_languages    102335 non-null  object
#  24  cast                102334 non-null  object
#  25  director            102418 non-null  object
#  26  imdb_rating         102438 non-null  float64
#  27  imdb_votes          102438 non-null  float64
# dtypes: datetime64[ns](1), float64(10), int64(5), object(12)
# memory usage: 21.9+ MB

# %%
# Displaying the 11 newly added rows
new_rows = imdb_merged_data.loc[~imdb_merged_data.index.isin(data_df.index)]
new_rows
# Out:
#         userId  movieId  user_rating    user_rating_time  \
# 102677     610   161634          4.0 2017-05-03 21:52:42
# 102678     610   162350          3.5 2017-05-03 22:19:31
# 102679     610   163937          3.5 2017-05-03 21:59:49
# 102680     610   163981          3.5 2017-05-03 22:22:35
# 102681     610   164179          5.0 2017-05-03 21:07:11
# 102682     610   166528          4.0 2017-05-04 06:29:25
# 102683     610   166534          4.0 2017-05-03 21:53:22
# 102684     610   168248          5.0 2017-05-03 22:21:31
# 102685     610   168250          5.0 2017-05-08 19:50:47
# 102686     610   168252          5.0 2017-05-03 21:19:12
# 102687     610   170875          3.0 2017-05-03 21:20:15
#
#                              title_x                              genres_x  \
# 102677                 Don't Breathe                            [Thriller]
# 102678         The Magnificent Seven                     [Action, Western]
# 102679                   Blair Witch                    [Horror, Thriller]
# 102680                            31                              [Horror]
# 102681                       Arrival                              [Sci-Fi]
# 102682  Rogue One: A Star Wars Story  [Action, Adventure, Fantasy, Sci-Fi]
# 102683                         Split             [Drama, Horror, Thriller]
# 102684        John Wick: Chapter Two             [Action, Crime, Thriller]
# 102685                       Get Out                              [Horror]
# 102686                         Logan                      [Action, Sci-Fi]
# 102687       The Fate of the Furious      [Action, Crime, Drama, Thriller]
#
#         release_year               tag   imdbId  total_user_ratings  ...  \
# 102677          2016           Unknown  4160708                   5  ...
# 102678          2016           Unknown  2404435                   6  ...
# 102679          2016           Unknown  1540011                   1  ...
# 102680          2016           Unknown  3835080                   1  ...
# 102681          2016           Unknown  2543164                  32  ...
# 102682          2016           Unknown  3748528                  27  ...
# 102683          2017           Unknown  4972582                   6  ...
# 102684          2017  Heroic Bloodshed  4425200                  13  ...
# 102685          2017           Unknown  5052448                  15  ...
# 102686          2017           Unknown  3315342                  29  ...
# 102687          2017           Unknown  4630562                   3  ...
#
#           imdb_id                                           overview  \
# 102677  tt4160708  A group of teens break into a blind man's home...
# 102678  tt2404435  Looking to mine for gold, greedy industrialist...
# 102679  tt1540011  Students on a camping trip discover something ...
# 102680  tt3835080  Five carnival workers are kidnapped and held h...
# 102681  tt2543164  Taking place after alien crafts land around th...
# 102682  tt3748528  A rogue band of resistance fighters unite for ...
# 102683  tt4972582  Though Kevin has evidenced 23 personalities to...
# 102684  tt4425200  John Wick is forced out of retirement by a for...
# 102685  tt5052448  Chris and his girlfriend Rose go upstate to vi...
# 102686  tt3315342  In the near future, a weary Logan cares for an...
# 102687  tt4630562  When a mysterious woman seduces Dom into the w...
#
#        popularity                                            tagline  \
# 102677     61.131  This house looked like an easy target, until t...
# 102678     54.382                              Justice has a number.
# 102679     23.043        There's something evil hiding in the woods.
# 102680     12.705                                   Welcome to hell.
# 102681     54.640                                 Why are they here?
# 102682     43.491                         A rebellion built on hope.
# 102683     70.505  Kevin has 23 distinct personalities. The 24th ...
# 102684    101.664                  Never stab the devil in the back!
# 102685     66.339  Just because you're invited, doesn't mean you'...
# 102686    159.281                                 His time has come.
# 102687     66.084                           Never give up on family.
#
#                                   genres_y  \
# 102677                    Horror, Thriller
# 102678          Adventure, Action, Western
# 102679                    Thriller, Horror
# 102680                    Horror, Thriller
# 102681     Drama, Science Fiction, Mystery
# 102682  Action, Adventure, Science Fiction
# 102683                    Horror, Thriller
# 102684             Action, Thriller, Crime
# 102685           Mystery, Thriller, Horror
# 102686      Action, Drama, Science Fiction
# 102687             Action, Crime, Thriller
#
#                             spoken_languages  \
# 102677                               English
# 102678                     English, Italiano
# 102679                               English
# 102680             Deutsch, English, Español
# 102681                 普通话, English, Pусский
# 102682                               English
# 102683                               English
# 102684  English, עִבְרִית, Italiano, Pусский
# 102685                               English
# 102686                      English, Español
# 102687                      English, Español
#
#                                                      cast            director  \
# 102677  Dylan Minnette, Stephen Lang, Franciska Törőcs...        Fede Álvarez
# 102678  Peter Sarsgaard, Manuel Garcia-Rulfo, Ed Lowry...       Antoine Fuqua
# 102679  Wes Robinson, James Allen McCune, Corbin Reid,...        Adam Wingard
# 102680  Gabriel Pimentel, Megan Albertus, Daniel Roebu...          Rob Zombie
# 102681  Christian Jadah, Leisa Reid, Ruth Chiang, Lori...    Denis Villeneuve
# 102682  Daniel Mays, John S. Schwartz, Warwick Davis, ...      Gareth Edwards
# 102683  John Jillard Sr., Jerome Gallman, Ann Wood, Al...  M. Night Shyamalan
# 102684  Thaddeus Daniels, Tim Connolly, Nobuya Shimamo...      Chad Stahelski
# 102685  Bradley Whitford, Lil Rel Howery, Keegan-Micha...        Jordan Peele
# 102686  Bryant Tardy, Daniel Hernández, Krzysztof Sosz...       James Mangold
# 102687  Anna MacKenzie Rogers, Caroline Kimmel, Alexan...        F. Gary Gray
#
#        imdb_rating imdb_votes
# 102677         7.1   306797.0
# 102678         6.9   231531.0
# 102679         5.0    50359.0
# 102680         5.1    23282.0
# 102681         7.9   785997.0
# 102682         7.8   696658.0
# 102683         7.3   566678.0
# 102684         7.4   521063.0
# 102685         7.8   720999.0
# 102686         8.1   856843.0
# 102687         6.6   257422.0
#
# [11 rows x 28 columns]

# %%
# Find the duplicate rows based on the 'imdbId' column
duplicate_rows = imdb_merged_data[imdb_merged_data['imdbId'].duplicated(keep=False)]
duplicate_rows
# Out:
#         userId  movieId  user_rating    user_rating_time  \
# 0            1        1          4.0 2000-07-30 18:45:03
# 1            1        3          4.0 2000-07-30 18:20:47
# 2            1        6          4.0 2000-07-30 18:37:04
# 3            1       47          5.0 2000-07-30 19:03:35
# 4            1       50          5.0 2000-07-30 18:48:51
# ...        ...      ...          ...                 ...
# 102683     610   166534          4.0 2017-05-03 21:53:22
# 102684     610   168248          5.0 2017-05-03 22:21:31
# 102685     610   168250          5.0 2017-05-08 19:50:47
# 102686     610   168252          5.0 2017-05-03 21:19:12
# 102687     610   170875          3.0 2017-05-03 21:20:15
#
#                         title_x  \
# 0                     Toy Story
# 1              Grumpier Old Men
# 2                          Heat
# 3          Seven (a.k.a. Se7en)
# 4           Usual Suspects, The
# ...                         ...
# 102683                    Split
# 102684   John Wick: Chapter Two
# 102685                  Get Out
# 102686                    Logan
# 102687  The Fate of the Furious
#
#                                                  genres_x  release_year  \
# 0       [Adventure, Animation, Children, Comedy, Fantasy]          1995
# 1                                       [Comedy, Romance]          1995
# 2                               [Action, Crime, Thriller]          1995
# 3                                     [Mystery, Thriller]          1995
# 4                              [Crime, Mystery, Thriller]          1995
# ...                                                   ...           ...
# 102683                          [Drama, Horror, Thriller]          2017
# 102684                          [Action, Crime, Thriller]          2017
# 102685                                           [Horror]          2017
# 102686                                   [Action, Sci-Fi]          2017
# 102687                   [Action, Crime, Drama, Thriller]          2017
#
#                      tag   imdbId  total_user_ratings  ...    imdb_id  \
# 0                Unknown   114709                 215  ...  tt0114709
# 1                Unknown   113228                  53  ...  tt0113228
# 2                Unknown   113277                 102  ...  tt0113277
# 3                Unknown   114369                 204  ...  tt0114369
# 4                Unknown   114814                 208  ...  tt0114814
# ...                  ...      ...                 ...  ...        ...
# 102683           Unknown  4972582                   6  ...  tt4972582
# 102684  Heroic Bloodshed  4425200                  13  ...  tt4425200
# 102685           Unknown  5052448                  15  ...  tt5052448
# 102686           Unknown  3315342                  29  ...  tt3315342
# 102687           Unknown  4630562                   3  ...  tt4630562
#
#                                                  overview popularity  \
# 0       Led by Woody, Andy's toys live happily in his ...    135.530
# 1       A family wedding reignites the ancient feud be...     11.833
# 2       Obsessive master thief Neil McCauley leads a t...     48.869
# 3       Two homicide detectives are on a desperate hun...    108.020
# 4       Held in an L.A. interrogation room, Verbal Kin...     41.143
# ...                                                   ...        ...
# 102683  Though Kevin has evidenced 23 personalities to...     70.505
# 102684  John Wick is forced out of retirement by a for...    101.664
# 102685  Chris and his girlfriend Rose go upstate to vi...     66.339
# 102686  In the near future, a weary Logan cares for an...    159.281
# 102687  When a mysterious woman seduces Dom into the w...     66.084
#
#                                                   tagline  \
# 0       Hang on for the comedy that goes to infinity a...
# 1       Still Yelling. Still Fighting. Still Ready for...
# 2                               A Los Angeles crime saga.
# 3                   Seven deadly sins. Seven ways to die.
# 4            Five criminals. One line up. No coincidence.
# ...                                                   ...
# 102683  Kevin has 23 distinct personalities. The 24th ...
# 102684                  Never stab the devil in the back!
# 102685  Just because you're invited, doesn't mean you'...
# 102686                                 His time has come.
# 102687                           Never give up on family.
#
#                                     genres_y  \
# 0       Animation, Adventure, Family, Comedy
# 1                            Romance, Comedy
# 2                       Action, Crime, Drama
# 3                   Crime, Mystery, Thriller
# 4                     Drama, Crime, Thriller
# ...                                      ...
# 102683                      Horror, Thriller
# 102684               Action, Thriller, Crime
# 102685             Mystery, Thriller, Horror
# 102686        Action, Drama, Science Fiction
# 102687               Action, Crime, Thriller
#
#                             spoken_languages  \
# 0                                    English
# 1                                    English
# 2                           English, Español
# 3                                    English
# 4         Español, English, Français, Magyar
# ...                                      ...
# 102683                               English
# 102684  English, עִבְרִית, Italiano, Pусский
# 102685                               English
# 102686                      English, Español
# 102687                      English, Español
#
#                                                      cast            director  \
# 0       Penn Jillette, Jim Varney, Annie Potts, John L...       John Lasseter
# 1       Sophia Loren, Jack Lemmon, Burgess Meredith, W...       Howard Deutch
# 2       Henry Rollins, Rick Marzan, Mick Gould, Kai So...        Michael Mann
# 3       Shannon Wilcox, Hawthorne James, Allan Kolman,...       David Fincher
# 4       Dan Hedaya, Gabriel Byrne, Stephen Baldwin, Gi...        Bryan Singer
# ...                                                   ...                 ...
# 102683  John Jillard Sr., Jerome Gallman, Ann Wood, Al...  M. Night Shyamalan
# 102684  Thaddeus Daniels, Tim Connolly, Nobuya Shimamo...      Chad Stahelski
# 102685  Bradley Whitford, Lil Rel Howery, Keegan-Micha...        Jordan Peele
# 102686  Bryant Tardy, Daniel Hernández, Krzysztof Sosz...       James Mangold
# 102687  Anna MacKenzie Rogers, Caroline Kimmel, Alexan...        F. Gary Gray
#
#        imdb_rating imdb_votes
# 0              8.3  1084026.0
# 1              6.7    30004.0
# 2              8.3   729795.0
# 3              8.6  1829387.0
# 4              8.5  1157914.0
# ...            ...        ...
# 102683         7.3   566678.0
# 102684         7.4   521063.0
# 102685         7.8   720999.0
# 102686         8.1   856843.0
# 102687         6.6   257422.0
#
# [99279 rows x 28 columns]

# %%
import pandas as pd

# Count duplicates in each column of a DataFrame
def count_duplicates(df):
    duplicates_count = {}
    for column in df.columns:
        duplicates_count[column] = df.duplicated(subset=[column]).sum()
    return duplicates_count

# Count duplicates in data_df
data_df_duplicates = count_duplicates(data_df)
print("Duplicates in data_df:")
print(data_df_duplicates)

# Count duplicates in imdb_data
imdb_df_duplicates = count_duplicates(imdb_df)
print("\nDuplicates in imdb_df:")
print(imdb_df_duplicates)

# Count duplicates in imdb_data
imdb_merged_df_duplicates = count_duplicates(imdb_merged_data)
print("\nDuplicates in imdb_merged_data:")
print(imdb_merged_df_duplicates)
# Out:
# Duplicates in data_df:
# {'userId': np.int64(102067), 'movieId': np.int64(92953), 'user_rating': np.int64(102667), 'user_rating_time': np.int64(17634), 'title': np.int64(93231), 'genres': np.int64(101726), 'release_year': np.int64(102571), 'tag': np.int64(101133), 'imdbId': np.int64(92953), 'total_user_ratings': np.int64(102497), 'average_rating': np.int64(102634), 'num_genres': np.int64(102668)}
#
# Duplicates in imdb_df:
# {'title': np.int64(144001), 'vote_average': np.int64(975590), 'vote_count': np.int64(976035), 'revenue': np.int64(964165), 'runtime': np.int64(979088), 'budget': np.int64(974012), 'imdb_id': np.int64(402650), 'overview': np.int64(186354), 'popularity': np.int64(953221), 'tagline': np.int64(838617), 'genres': np.int64(965814), 'spoken_languages': np.int64(973139), 'cast': np.int64(365866), 'director': np.int64(653351), 'imdb_rating': np.int64(979715), 'imdb_votes': np.int64(960632), 'imdbId': np.int64(402650)}
#
# Duplicates in imdb_merged_data:
# {'userId': np.int64(102078), 'movieId': np.int64(92964), 'user_rating': np.int64(102678), 'user_rating_time': np.int64(17645), 'title_x': np.int64(93242), 'genres_x': np.int64(101737), 'release_year': np.int64(102582), 'tag': np.int64(101144), 'imdbId': np.int64(92964), 'total_user_ratings': np.int64(102508), 'average_rating': np.int64(102645), 'num_genres': np.int64(102679), 'title_y': np.int64(93371), 'vote_average': np.int64(100513), 'vote_count': np.int64(99404), 'revenue': np.int64(96932), 'runtime': np.int64(102464), 'budget': np.int64(101960), 'imdb_id': np.int64(93055), 'overview': np.int64(93074), 'popularity': np.int64(94126), 'tagline': np.int64(94479), 'genres_y': np.int64(100699), 'spoken_languages': np.int64(101735), 'cast': np.int64(93127), 'director': np.int64(98548), 'imdb_rating': np.int64(102612), 'imdb_votes': np.int64(93609)}

# %%
# Replacing 'Unknown' with NaN in the 'tag' & 'tagline' column
imdb_merged_data['tag'] = imdb_merged_data['tag'].replace('Unknown', '')
imdb_merged_data['tagline'] = imdb_merged_data['tagline'].replace('NaN', '')
imdb_merged_data
# Out:
#         userId  movieId  user_rating    user_rating_time  \
# 0            1        1          4.0 2000-07-30 18:45:03
# 1            1        3          4.0 2000-07-30 18:20:47
# 2            1        6          4.0 2000-07-30 18:37:04
# 3            1       47          5.0 2000-07-30 19:03:35
# 4            1       50          5.0 2000-07-30 18:48:51
# ...        ...      ...          ...                 ...
# 102683     610   166534          4.0 2017-05-03 21:53:22
# 102684     610   168248          5.0 2017-05-03 22:21:31
# 102685     610   168250          5.0 2017-05-08 19:50:47
# 102686     610   168252          5.0 2017-05-03 21:19:12
# 102687     610   170875          3.0 2017-05-03 21:20:15
#
#                         title_x  \
# 0                     Toy Story
# 1              Grumpier Old Men
# 2                          Heat
# 3          Seven (a.k.a. Se7en)
# 4           Usual Suspects, The
# ...                         ...
# 102683                    Split
# 102684   John Wick: Chapter Two
# 102685                  Get Out
# 102686                    Logan
# 102687  The Fate of the Furious
#
#                                                  genres_x  release_year  \
# 0       [Adventure, Animation, Children, Comedy, Fantasy]          1995
# 1                                       [Comedy, Romance]          1995
# 2                               [Action, Crime, Thriller]          1995
# 3                                     [Mystery, Thriller]          1995
# 4                              [Crime, Mystery, Thriller]          1995
# ...                                                   ...           ...
# 102683                          [Drama, Horror, Thriller]          2017
# 102684                          [Action, Crime, Thriller]          2017
# 102685                                           [Horror]          2017
# 102686                                   [Action, Sci-Fi]          2017
# 102687                   [Action, Crime, Drama, Thriller]          2017
#
#                      tag   imdbId  total_user_ratings  ...    imdb_id  \
# 0                          114709                 215  ...  tt0114709
# 1                          113228                  53  ...  tt0113228
# 2                          113277                 102  ...  tt0113277
# 3                          114369                 204  ...  tt0114369
# 4                          114814                 208  ...  tt0114814
# ...                  ...      ...                 ...  ...        ...
# 102683                    4972582                   6  ...  tt4972582
# 102684  Heroic Bloodshed  4425200                  13  ...  tt4425200
# 102685                    5052448                  15  ...  tt5052448
# 102686                    3315342                  29  ...  tt3315342
# 102687                    4630562                   3  ...  tt4630562
#
#                                                  overview popularity  \
# 0       Led by Woody, Andy's toys live happily in his ...    135.530
# 1       A family wedding reignites the ancient feud be...     11.833
# 2       Obsessive master thief Neil McCauley leads a t...     48.869
# 3       Two homicide detectives are on a desperate hun...    108.020
# 4       Held in an L.A. interrogation room, Verbal Kin...     41.143
# ...                                                   ...        ...
# 102683  Though Kevin has evidenced 23 personalities to...     70.505
# 102684  John Wick is forced out of retirement by a for...    101.664
# 102685  Chris and his girlfriend Rose go upstate to vi...     66.339
# 102686  In the near future, a weary Logan cares for an...    159.281
# 102687  When a mysterious woman seduces Dom into the w...     66.084
#
#                                                   tagline  \
# 0       Hang on for the comedy that goes to infinity a...
# 1       Still Yelling. Still Fighting. Still Ready for...
# 2                               A Los Angeles crime saga.
# 3                   Seven deadly sins. Seven ways to die.
# 4            Five criminals. One line up. No coincidence.
# ...                                                   ...
# 102683  Kevin has 23 distinct personalities. The 24th ...
# 102684                  Never stab the devil in the back!
# 102685  Just because you're invited, doesn't mean you'...
# 102686                                 His time has come.
# 102687                           Never give up on family.
#
#                                     genres_y  \
# 0       Animation, Adventure, Family, Comedy
# 1                            Romance, Comedy
# 2                       Action, Crime, Drama
# 3                   Crime, Mystery, Thriller
# 4                     Drama, Crime, Thriller
# ...                                      ...
# 102683                      Horror, Thriller
# 102684               Action, Thriller, Crime
# 102685             Mystery, Thriller, Horror
# 102686        Action, Drama, Science Fiction
# 102687               Action, Crime, Thriller
#
#                             spoken_languages  \
# 0                                    English
# 1                                    English
# 2                           English, Español
# 3                                    English
# 4         Español, English, Français, Magyar
# ...                                      ...
# 102683                               English
# 102684  English, עִבְרִית, Italiano, Pусский
# 102685                               English
# 102686                      English, Español
# 102687                      English, Español
#
#                                                      cast            director  \
# 0       Penn Jillette, Jim Varney, Annie Potts, John L...       John Lasseter
# 1       Sophia Loren, Jack Lemmon, Burgess Meredith, W...       Howard Deutch
# 2       Henry Rollins, Rick Marzan, Mick Gould, Kai So...        Michael Mann
# 3       Shannon Wilcox, Hawthorne James, Allan Kolman,...       David Fincher
# 4       Dan Hedaya, Gabriel Byrne, Stephen Baldwin, Gi...        Bryan Singer
# ...                                                   ...                 ...
# 102683  John Jillard Sr., Jerome Gallman, Ann Wood, Al...  M. Night Shyamalan
# 102684  Thaddeus Daniels, Tim Connolly, Nobuya Shimamo...      Chad Stahelski
# 102685  Bradley Whitford, Lil Rel Howery, Keegan-Micha...        Jordan Peele
# 102686  Bryant Tardy, Daniel Hernández, Krzysztof Sosz...       James Mangold
# 102687  Anna MacKenzie Rogers, Caroline Kimmel, Alexan...        F. Gary Gray
#
#        imdb_rating imdb_votes
# 0              8.3  1084026.0
# 1              6.7    30004.0
# 2              8.3   729795.0
# 3              8.6  1829387.0
# 4              8.5  1157914.0
# ...            ...        ...
# 102683         7.3   566678.0
# 102684         7.4   521063.0
# 102685         7.8   720999.0
# 102686         8.1   856843.0
# 102687         6.6   257422.0
#
# [102688 rows x 28 columns]

# %%
# Merging 'tag' and 'tagline'
#imdb_merged_data['merged_tag'] = imdb_merged_data.apply(
#    lambda row: (
#        row['tag'] if row['tag'] and row['tagline'] == '' else
#        row['tagline'] if row['tagline'] and row['tag'] == '' else
#        ', '.join([str(row['tag']), str(row['tagline'])]).strip(', ') if row['tag'] and row['tagline'] else
#        'Unknown'
#    ), axis=1)
#
#imdb_merged_data

# %%
# Genres to String
imdb_merged_data['genres_x'] = imdb_merged_data['genres_x'].apply(lambda x: ', '.join(x) if x else 'Unknown')
imdb_merged_data
# Out:
#         userId  movieId  user_rating    user_rating_time  \
# 0            1        1          4.0 2000-07-30 18:45:03
# 1            1        3          4.0 2000-07-30 18:20:47
# 2            1        6          4.0 2000-07-30 18:37:04
# 3            1       47          5.0 2000-07-30 19:03:35
# 4            1       50          5.0 2000-07-30 18:48:51
# ...        ...      ...          ...                 ...
# 102683     610   166534          4.0 2017-05-03 21:53:22
# 102684     610   168248          5.0 2017-05-03 22:21:31
# 102685     610   168250          5.0 2017-05-08 19:50:47
# 102686     610   168252          5.0 2017-05-03 21:19:12
# 102687     610   170875          3.0 2017-05-03 21:20:15
#
#                         title_x  \
# 0                     Toy Story
# 1              Grumpier Old Men
# 2                          Heat
# 3          Seven (a.k.a. Se7en)
# 4           Usual Suspects, The
# ...                         ...
# 102683                    Split
# 102684   John Wick: Chapter Two
# 102685                  Get Out
# 102686                    Logan
# 102687  The Fate of the Furious
#
#                                                genres_x  release_year  \
# 0       Adventure, Animation, Children, Comedy, Fantasy          1995
# 1                                       Comedy, Romance          1995
# 2                               Action, Crime, Thriller          1995
# 3                                     Mystery, Thriller          1995
# 4                              Crime, Mystery, Thriller          1995
# ...                                                 ...           ...
# 102683                          Drama, Horror, Thriller          2017
# 102684                          Action, Crime, Thriller          2017
# 102685                                           Horror          2017
# 102686                                   Action, Sci-Fi          2017
# 102687                   Action, Crime, Drama, Thriller          2017
#
#                      tag   imdbId  total_user_ratings  ...    imdb_id  \
# 0                          114709                 215  ...  tt0114709
# 1                          113228                  53  ...  tt0113228
# 2                          113277                 102  ...  tt0113277
# 3                          114369                 204  ...  tt0114369
# 4                          114814                 208  ...  tt0114814
# ...                  ...      ...                 ...  ...        ...
# 102683                    4972582                   6  ...  tt4972582
# 102684  Heroic Bloodshed  4425200                  13  ...  tt4425200
# 102685                    5052448                  15  ...  tt5052448
# 102686                    3315342                  29  ...  tt3315342
# 102687                    4630562                   3  ...  tt4630562
#
#                                                  overview popularity  \
# 0       Led by Woody, Andy's toys live happily in his ...    135.530
# 1       A family wedding reignites the ancient feud be...     11.833
# 2       Obsessive master thief Neil McCauley leads a t...     48.869
# 3       Two homicide detectives are on a desperate hun...    108.020
# 4       Held in an L.A. interrogation room, Verbal Kin...     41.143
# ...                                                   ...        ...
# 102683  Though Kevin has evidenced 23 personalities to...     70.505
# 102684  John Wick is forced out of retirement by a for...    101.664
# 102685  Chris and his girlfriend Rose go upstate to vi...     66.339
# 102686  In the near future, a weary Logan cares for an...    159.281
# 102687  When a mysterious woman seduces Dom into the w...     66.084
#
#                                                   tagline  \
# 0       Hang on for the comedy that goes to infinity a...
# 1       Still Yelling. Still Fighting. Still Ready for...
# 2                               A Los Angeles crime saga.
# 3                   Seven deadly sins. Seven ways to die.
# 4            Five criminals. One line up. No coincidence.
# ...                                                   ...
# 102683  Kevin has 23 distinct personalities. The 24th ...
# 102684                  Never stab the devil in the back!
# 102685  Just because you're invited, doesn't mean you'...
# 102686                                 His time has come.
# 102687                           Never give up on family.
#
#                                     genres_y  \
# 0       Animation, Adventure, Family, Comedy
# 1                            Romance, Comedy
# 2                       Action, Crime, Drama
# 3                   Crime, Mystery, Thriller
# 4                     Drama, Crime, Thriller
# ...                                      ...
# 102683                      Horror, Thriller
# 102684               Action, Thriller, Crime
# 102685             Mystery, Thriller, Horror
# 102686        Action, Drama, Science Fiction
# 102687               Action, Crime, Thriller
#
#                             spoken_languages  \
# 0                                    English
# 1                                    English
# 2                           English, Español
# 3                                    English
# 4         Español, English, Français, Magyar
# ...                                      ...
# 102683                               English
# 102684  English, עִבְרִית, Italiano, Pусский
# 102685                               English
# 102686                      English, Español
# 102687                      English, Español
#
#                                                      cast            director  \
# 0       Penn Jillette, Jim Varney, Annie Potts, John L...       John Lasseter
# 1       Sophia Loren, Jack Lemmon, Burgess Meredith, W...       Howard Deutch
# 2       Henry Rollins, Rick Marzan, Mick Gould, Kai So...        Michael Mann
# 3       Shannon Wilcox, Hawthorne James, Allan Kolman,...       David Fincher
# 4       Dan Hedaya, Gabriel Byrne, Stephen Baldwin, Gi...        Bryan Singer
# ...                                                   ...                 ...
# 102683  John Jillard Sr., Jerome Gallman, Ann Wood, Al...  M. Night Shyamalan
# 102684  Thaddeus Daniels, Tim Connolly, Nobuya Shimamo...      Chad Stahelski
# 102685  Bradley Whitford, Lil Rel Howery, Keegan-Micha...        Jordan Peele
# 102686  Bryant Tardy, Daniel Hernández, Krzysztof Sosz...       James Mangold
# 102687  Anna MacKenzie Rogers, Caroline Kimmel, Alexan...        F. Gary Gray
#
#        imdb_rating imdb_votes
# 0              8.3  1084026.0
# 1              6.7    30004.0
# 2              8.3   729795.0
# 3              8.6  1829387.0
# 4              8.5  1157914.0
# ...            ...        ...
# 102683         7.3   566678.0
# 102684         7.4   521063.0
# 102685         7.8   720999.0
# 102686         8.1   856843.0
# 102687         6.6   257422.0
#
# [102688 rows x 28 columns]

# %%
# Merge genres based on conditions
def merge_genres(row):
    genres_x_set = set(x.strip() for x in row['genres_x'].split(',')) if isinstance(row['genres_x'], str) else set()
    genres_y_set = set(y.strip() for y in row['genres_y'].split(',')) if isinstance(row['genres_y'], str) else set()

    if genres_x_set and not genres_y_set:
        return ', '.join(sorted(genres_x_set))
    elif genres_y_set and not genres_x_set:
        return ', '.join(sorted(genres_y_set))
    elif genres_x_set and genres_y_set:
        combined_genres = sorted(genres_x_set.union(genres_y_set))
        return ', '.join(combined_genres)
    else:
        return 'Unknown'

imdb_merged_data['merged_genres'] = imdb_merged_data.apply(merge_genres, axis=1)

# %%
imdb_merged_data.isnull().sum()
# Out:
# userId                   0
# movieId                  0
# user_rating              0
# user_rating_time         0
# title_x                  0
# genres_x                 0
# release_year             0
# tag                      0
# imdbId                   0
# total_user_ratings       0
# average_rating           0
# num_genres               0
# title_y                249
# vote_average           249
# vote_count             249
# revenue                249
# runtime                249
# budget                 249
# imdb_id                249
# overview               259
# popularity             249
# tagline               3774
# genres_y               255
# spoken_languages       353
# cast                   354
# director               270
# imdb_rating            250
# imdb_votes             250
# merged_genres            0
# dtype: int64

# %%
# Keeping the Lead Actors from "cast" column
def keep_first_two_cast(cast_str):
    if isinstance(cast_str, str):
        cast_list = cast_str.split(', ')
        return ', '.join(cast_list[:2])
    return cast_str

# Apply
imdb_merged_data['cast'] = imdb_merged_data['cast'].apply(keep_first_two_cast)
imdb_merged_data
# Out:
#         userId  movieId  user_rating    user_rating_time  \
# 0            1        1          4.0 2000-07-30 18:45:03
# 1            1        3          4.0 2000-07-30 18:20:47
# 2            1        6          4.0 2000-07-30 18:37:04
# 3            1       47          5.0 2000-07-30 19:03:35
# 4            1       50          5.0 2000-07-30 18:48:51
# ...        ...      ...          ...                 ...
# 102683     610   166534          4.0 2017-05-03 21:53:22
# 102684     610   168248          5.0 2017-05-03 22:21:31
# 102685     610   168250          5.0 2017-05-08 19:50:47
# 102686     610   168252          5.0 2017-05-03 21:19:12
# 102687     610   170875          3.0 2017-05-03 21:20:15
#
#                         title_x  \
# 0                     Toy Story
# 1              Grumpier Old Men
# 2                          Heat
# 3          Seven (a.k.a. Se7en)
# 4           Usual Suspects, The
# ...                         ...
# 102683                    Split
# 102684   John Wick: Chapter Two
# 102685                  Get Out
# 102686                    Logan
# 102687  The Fate of the Furious
#
#                                                genres_x  release_year  \
# 0       Adventure, Animation, Children, Comedy, Fantasy          1995
# 1                                       Comedy, Romance          1995
# 2                               Action, Crime, Thriller          1995
# 3                                     Mystery, Thriller          1995
# 4                              Crime, Mystery, Thriller          1995
# ...                                                 ...           ...
# 102683                          Drama, Horror, Thriller          2017
# 102684                          Action, Crime, Thriller          2017
# 102685                                           Horror          2017
# 102686                                   Action, Sci-Fi          2017
# 102687                   Action, Crime, Drama, Thriller          2017
#
#                      tag   imdbId  total_user_ratings  ...  \
# 0                          114709                 215  ...
# 1                          113228                  53  ...
# 2                          113277                 102  ...
# 3                          114369                 204  ...
# 4                          114814                 208  ...
# ...                  ...      ...                 ...  ...
# 102683                    4972582                   6  ...
# 102684  Heroic Bloodshed  4425200                  13  ...
# 102685                    5052448                  15  ...
# 102686                    3315342                  29  ...
# 102687                    4630562                   3  ...
#
#                                                  overview  popularity  \
# 0       Led by Woody, Andy's toys live happily in his ...     135.530
# 1       A family wedding reignites the ancient feud be...      11.833
# 2       Obsessive master thief Neil McCauley leads a t...      48.869
# 3       Two homicide detectives are on a desperate hun...     108.020
# 4       Held in an L.A. interrogation room, Verbal Kin...      41.143
# ...                                                   ...         ...
# 102683  Though Kevin has evidenced 23 personalities to...      70.505
# 102684  John Wick is forced out of retirement by a for...     101.664
# 102685  Chris and his girlfriend Rose go upstate to vi...      66.339
# 102686  In the near future, a weary Logan cares for an...     159.281
# 102687  When a mysterious woman seduces Dom into the w...      66.084
#
#                                                   tagline  \
# 0       Hang on for the comedy that goes to infinity a...
# 1       Still Yelling. Still Fighting. Still Ready for...
# 2                               A Los Angeles crime saga.
# 3                   Seven deadly sins. Seven ways to die.
# 4            Five criminals. One line up. No coincidence.
# ...                                                   ...
# 102683  Kevin has 23 distinct personalities. The 24th ...
# 102684                  Never stab the devil in the back!
# 102685  Just because you're invited, doesn't mean you'...
# 102686                                 His time has come.
# 102687                           Never give up on family.
#
#                                     genres_y  \
# 0       Animation, Adventure, Family, Comedy
# 1                            Romance, Comedy
# 2                       Action, Crime, Drama
# 3                   Crime, Mystery, Thriller
# 4                     Drama, Crime, Thriller
# ...                                      ...
# 102683                      Horror, Thriller
# 102684               Action, Thriller, Crime
# 102685             Mystery, Thriller, Horror
# 102686        Action, Drama, Science Fiction
# 102687               Action, Crime, Thriller
#
#                             spoken_languages  \
# 0                                    English
# 1                                    English
# 2                           English, Español
# 3                                    English
# 4         Español, English, Français, Magyar
# ...                                      ...
# 102683                               English
# 102684  English, עִבְרִית, Italiano, Pусский
# 102685                               English
# 102686                      English, Español
# 102687                      English, Español
#
#                                           cast            director  \
# 0                    Penn Jillette, Jim Varney       John Lasseter
# 1                    Sophia Loren, Jack Lemmon       Howard Deutch
# 2                   Henry Rollins, Rick Marzan        Michael Mann
# 3              Shannon Wilcox, Hawthorne James       David Fincher
# 4                    Dan Hedaya, Gabriel Byrne        Bryan Singer
# ...                                        ...                 ...
# 102683        John Jillard Sr., Jerome Gallman  M. Night Shyamalan
# 102684          Thaddeus Daniels, Tim Connolly      Chad Stahelski
# 102685        Bradley Whitford, Lil Rel Howery        Jordan Peele
# 102686          Bryant Tardy, Daniel Hernández       James Mangold
# 102687  Anna MacKenzie Rogers, Caroline Kimmel        F. Gary Gray
#
#         imdb_rating imdb_votes  \
# 0               8.3  1084026.0
# 1               6.7    30004.0
# 2               8.3   729795.0
# 3               8.6  1829387.0
# 4               8.5  1157914.0
# ...             ...        ...
# 102683          7.3   566678.0
# 102684          7.4   521063.0
# 102685          7.8   720999.0
# 102686          8.1   856843.0
# 102687          6.6   257422.0
#
#                                             merged_genres
# 0       Adventure, Animation, Children, Comedy, Family...
# 1                                         Comedy, Romance
# 2                          Action, Crime, Drama, Thriller
# 3                                Crime, Mystery, Thriller
# 4                         Crime, Drama, Mystery, Thriller
# ...                                                   ...
# 102683                            Drama, Horror, Thriller
# 102684                            Action, Crime, Thriller
# 102685                          Horror, Mystery, Thriller
# 102686             Action, Drama, Sci-Fi, Science Fiction
# 102687                     Action, Crime, Drama, Thriller
#
# [102688 rows x 29 columns]

# %%
imdb_merged_data = imdb_merged_data.drop(columns=["title_y"])
imdb_merged_data = imdb_merged_data.drop(columns=["genres_x"])
imdb_merged_data = imdb_merged_data.drop(columns=["genres_y"])
imdb_merged_data = imdb_merged_data.drop(columns=["spoken_languages"])
imdb_merged_data.isnull().sum()
# Out:
# userId                   0
# movieId                  0
# user_rating              0
# user_rating_time         0
# title_x                  0
# release_year             0
# tag                      0
# imdbId                   0
# total_user_ratings       0
# average_rating           0
# num_genres               0
# vote_average           249
# vote_count             249
# revenue                249
# runtime                249
# budget                 249
# imdb_id                249
# overview               259
# popularity             249
# tagline               3774
# cast                   354
# director               270
# imdb_rating            250
# imdb_votes             250
# merged_genres            0
# dtype: int64

# %%
imdb_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102688 entries, 0 to 102687
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   userId              102688 non-null  int64
#  1   movieId             102688 non-null  int64
#  2   user_rating         102688 non-null  float64
#  3   user_rating_time    102688 non-null  datetime64[ns]
#  4   title_x             102688 non-null  object
#  5   release_year        102688 non-null  int64
#  6   tag                 102688 non-null  object
#  7   imdbId              102688 non-null  object
#  8   total_user_ratings  102688 non-null  int64
#  9   average_rating      102688 non-null  float64
#  10  num_genres          102688 non-null  int64
#  11  vote_average        102439 non-null  float64
#  12  vote_count          102439 non-null  float64
#  13  revenue             102439 non-null  float64
#  14  runtime             102439 non-null  float64
#  15  budget              102439 non-null  float64
#  16  imdb_id             102439 non-null  object
#  17  overview            102429 non-null  object
#  18  popularity          102439 non-null  float64
#  19  tagline             98914 non-null   object
#  20  cast                102334 non-null  object
#  21  director            102418 non-null  object
#  22  imdb_rating         102438 non-null  float64
#  23  imdb_votes          102438 non-null  float64
#  24  merged_genres       102688 non-null  object
# dtypes: datetime64[ns](1), float64(10), int64(5), object(9)
# memory usage: 19.6+ MB

# %%
# Define a dictionary with the current column names as keys and the new column names as values
new_column_names = {
    'rating': 'user_rating',
    'timestamp': 'user_rating_time',
    'title_x': 'title',
    'year': 'release_year',
    'number_of_ratings': 'total_user_ratings',
    'vote_average': 'tmdb_vote_average',
    'vote_count': 'tmdb_vote_count',
    'overview': 'description',
    'cast': 'cast_actors',
    'tagline': 'imbd_tagline',
    'tag': 'user_tag',
    'merged_genres': 'genres',
    # Add more columns as needed
}

# Rename the columns using the dictionary
imdb_merged_data = imdb_merged_data.rename(columns=new_column_names)
imdb_merged_data.head()
# Out:
#    userId  movieId  user_rating    user_rating_time                 title  \
# 0       1        1          4.0 2000-07-30 18:45:03             Toy Story
# 1       1        3          4.0 2000-07-30 18:20:47      Grumpier Old Men
# 2       1        6          4.0 2000-07-30 18:37:04                  Heat
# 3       1       47          5.0 2000-07-30 19:03:35  Seven (a.k.a. Se7en)
# 4       1       50          5.0 2000-07-30 18:48:51   Usual Suspects, The
#
#    release_year user_tag  imdbId  total_user_ratings  average_rating  ...  \
# 0          1995           114709                 215             3.9  ...
# 1          1995           113228                  53             3.2  ...
# 2          1995           113277                 102             3.9  ...
# 3          1995           114369                 204             4.0  ...
# 4          1995           114814                 208             4.3  ...
#
#        budget    imdb_id                                        description  \
# 0  30000000.0  tt0114709  Led by Woody, Andy's toys live happily in his ...
# 1  25000000.0  tt0113228  A family wedding reignites the ancient feud be...
# 2  60000000.0  tt0113277  Obsessive master thief Neil McCauley leads a t...
# 3  33000000.0  tt0114369  Two homicide detectives are on a desperate hun...
# 4   6000000.0  tt0114814  Held in an L.A. interrogation room, Verbal Kin...
#
#    popularity                                       imbd_tagline  \
# 0     135.530  Hang on for the comedy that goes to infinity a...
# 1      11.833  Still Yelling. Still Fighting. Still Ready for...
# 2      48.869                          A Los Angeles crime saga.
# 3     108.020              Seven deadly sins. Seven ways to die.
# 4      41.143       Five criminals. One line up. No coincidence.
#
#                        cast_actors       director imdb_rating  imdb_votes  \
# 0        Penn Jillette, Jim Varney  John Lasseter         8.3   1084026.0
# 1        Sophia Loren, Jack Lemmon  Howard Deutch         6.7     30004.0
# 2       Henry Rollins, Rick Marzan   Michael Mann         8.3    729795.0
# 3  Shannon Wilcox, Hawthorne James  David Fincher         8.6   1829387.0
# 4        Dan Hedaya, Gabriel Byrne   Bryan Singer         8.5   1157914.0
#
#                                               genres
# 0  Adventure, Animation, Children, Comedy, Family...
# 1                                    Comedy, Romance
# 2                     Action, Crime, Drama, Thriller
# 3                           Crime, Mystery, Thriller
# 4                    Crime, Drama, Mystery, Thriller
#
# [5 rows x 25 columns]

# %%
imdb_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102688 entries, 0 to 102687
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   userId              102688 non-null  int64
#  1   movieId             102688 non-null  int64
#  2   user_rating         102688 non-null  float64
#  3   user_rating_time    102688 non-null  datetime64[ns]
#  4   title               102688 non-null  object
#  5   release_year        102688 non-null  int64
#  6   user_tag            102688 non-null  object
#  7   imdbId              102688 non-null  object
#  8   total_user_ratings  102688 non-null  int64
#  9   average_rating      102688 non-null  float64
#  10  num_genres          102688 non-null  int64
#  11  tmdb_vote_average   102439 non-null  float64
#  12  tmdb_vote_count     102439 non-null  float64
#  13  revenue             102439 non-null  float64
#  14  runtime             102439 non-null  float64
#  15  budget              102439 non-null  float64
#  16  imdb_id             102439 non-null  object
#  17  description         102429 non-null  object
#  18  popularity          102439 non-null  float64
#  19  imbd_tagline        98914 non-null   object
#  20  cast_actors         102334 non-null  object
#  21  director            102418 non-null  object
#  22  imdb_rating         102438 non-null  float64
#  23  imdb_votes          102438 non-null  float64
#  24  genres              102688 non-null  object
# dtypes: datetime64[ns](1), float64(10), int64(5), object(9)
# memory usage: 19.6+ MB

# %%
unique_values_per_column = imdb_merged_data.nunique()
print(unique_values_per_column)
# Out:
# userId                  610
# movieId                9724
# user_rating              10
# user_rating_time      85043
# title                  9446
# release_year            106
# user_tag               1544
# imdbId                 9724
# total_user_ratings      180
# average_rating           43
# num_genres                9
# tmdb_vote_average      2174
# tmdb_vote_count        3283
# revenue                5755
# runtime                 223
# budget                  727
# imdb_id                9632
# description            9613
# popularity             8561
# imbd_tagline           8208
# cast_actors            9550
# director               4139
# imdb_rating              75
# imdb_votes             9078
# genres                 1625
# dtype: int64
